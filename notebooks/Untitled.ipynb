# %% [markdown]
# # Task 4

# %% [markdown]
# ## Analysis 1

# %% [markdown]
# ## Analysis 2: Jaden

# %% [markdown]
# Research Question:
#     I would be interersted in doing a regression analysis or something along the lines, to see the relationship
#     between housing prices in California and other variables. These variables include distance from the coastline,
#     age of the house and number of bedrooms and bathrooms. I would also like to see the magnitude of how household
#     income positively affects house prices.

# %% [markdown]
# The variables I am particularily interested in exploring are income, house age, total rooms,
# and distance from the coast.

# %% [markdown]
# As expected, the Median income of a household has a large correlation coefficient of 0.69.
# There are many outliers above and below the regressional line. I find it interesting how many
# values are grouped on the right hand side, above and below the line. Due to limitations within
# our data, we cannot explore the implications of this. However, the outliers above the regressional
# line represent a modest population, who's income does not reflect the value of their house. The
# same could be said about the outliers below the regressional line, who potentially value a nicer
# living space as a portion of income than the rest of the population. However, another inference is
# that their house could have been purchased long ago, and have appreciated in value since then, while
# their income has not.

# %% [markdown]
# The distance from the coast has an anticipated negative correlation with median house value. People desire to
# be located near bodies of water. However, it has a slightly lower correlation with house value than income
# does, with a coefficient of -0.47. This reflects a potential average distribution of household quality across
# the analyzed region.

# %% [markdown]
# Surprisingly, the number of rooms in a household does not hold a large effect on the median house value.
# I would have expected a larger correlation strength than its value of 0.13. The several outliers way above
# the regressional line are interesting. Perhaps there may have been some lower end apartment complexes
# located within the specified block.

# %% [markdown]
# I initially predicted a negative correlation between household age and its value. With a coefficient of 0.11,
# the joint plot displays a small, but positive relationship between the two variables. Most capital goods
# depreciate in economic value over time, however houses do not follow this trend. While counterintuitve at first,
# it is logical. Due to the laws of supply and demand, house values appreciate over time, particularly when
# accounting for inflation. Cities were initially settled on the more prosperous and prime land, explaining
# why houses built before hold more value then new ones, geographically speaking.

# %% [markdown]
# Please refer to analysis2.ipynb for graphical visualizations.

# %% [markdown]
# ## Analysis 3: Nishant

# %% [markdown]
# Original Research Questions:
#
# 1. Correlation between housing prices and the distance to LA,SF,and the nearest coast to see how price is distributed geographically
#
# 2. Correlation between income levels and the distance to LA,SF,and the nearest coast to see how the population is distributed by income geographically

# %% [markdown]
# Change(s) to my research questions:
#
# N/A - Based on the correlational analaysis from the heatmap I produced, there appear to be no stronger correlations between any other combinations of variables, therefore I will not be adding any research questions to my existing 2.

# %%
plt.figure(figsize=(14,14))
sns.heatmap(houses.corr(),linewidths=.1,cmap="BuPu", annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# 1. Correlation between housing prices and the distance to LA,SF,and the nearest coast to see how price is distributed geographically
#
# Initially, my hypothesis was that in general, housing prices will tend to be lower the further you are from a big city such as Los Angeles or San Francisco.
#
# This proved to be somewhat true, however the data visualizations would indicate that the correlation between these variables are not as strong as I had initially expected them to be.
#
# - Housing Price vs Distance to LA : -0.13
# - Housing Price vs Distance to SF : -0.031
#
# From a statistical perspective, these numbers would go on to suggest that there is not really as much of a correlation between the variables , if any, at all.
#
# However, I was surprised to discover that the distance to the nearest coast did have a much stronger correlation than I had anticipated.
#
# - Housing Price vs Distance to nearest coast : -0.47
#
# The figure for the relationship above was a lot less vague in terms of visual patterns compared to the other two, and seemed to exhibit a general decline with increasing distance.
#
# Hence, my original hypothesis that housing prices tend to be greater the closer they are to Los Angeles or San Francisco has been disproven.

# %% [markdown]
# 2. Correlation between income levels and the distance to LA,SF,and the nearest coast to see how the population is distributed by income geographically
#
# The figures and relationships I used to answer this question are very similar to my previous research question.
#
# I had no hypothesis as to whether or not income varied by geography, since it is one of those things where multiple variables play a factor.
# However, I found it interesting that similar to last time, income had a higher correlation with the distance to the coast than than it did with
# the other 2 cities.
#
# - Income vs Distance to LA : -0.065
# - Income vs Distance to SF : -0.031
# - Income vs Distance to coast : -0.24
#
# Again, statistically, none of these values can be used to prove any sort of causality or correlation, hoowever, it was just interesting to note that the distance to the coast seems to have a lot more impact on both
# the average housing price and income in comparison to the dsitance to both LA and San Francisco.
